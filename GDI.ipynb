# %%
import pandas as pd
import csv

# %%
file = "GDI_data.csv"

# %%
raw_df = pd.read_csv(file, error_bad_lines=False, sep=",", encoding='cp1252', header =2)
raw_df.fillna(value=0)
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
clean_data = raw_df[['Country Name','2015','2016']]
clean_data.fillna(value=0)
clean_data.to_csv("clean_GDI_data.csv")

# %%
len(clean_data)
# Out:
# 264

# %%
clean_data.head()
# Out:
#   Country Name          2015          2016
# 0        Aruba           NaN           NaN
# 1  Afghanistan  4.801616e+11  4.970644e+11
# 2       Angola           NaN           NaN
# 3      Albania  6.474316e+11  6.548612e+11
# 4      Andorra           NaN           NaN
