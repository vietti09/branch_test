# %%
import pandas as pd
import csv

# %%
file = "GDI_data.csv"

# %%
raw_df = pd.read_csv(file, error_bad_lines=False, sep=",", encoding='cp1252', header =2)

raw_df.fillna(value=0)
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
file2 = "happiness_2015.csv"
file3 = "happiness_2016.csv"
raw_df2 = pd.read_csv(file2)
raw_df2
# Out:
#                       Country                           Region  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
raw_df3 = pd.read_csv(file3)
raw_df3
# Out:
#                   Country                           Region  Happiness Rank  \
# 0                 Denmark                   Western Europe               1
# 1             Switzerland                   Western Europe               2
# 2                 Iceland                   Western Europe               3
# 3                  Norway                   Western Europe               4
# 4                 Finland                   Western Europe               5
# 5                  Canada                    North America               6
# 6             Netherlands                   Western Europe               7
# 7             New Zealand        Australia and New Zealand               8
# 8               Australia        Australia and New Zealand               9
# 9                  Sweden                   Western Europe              10
# 10                 Israel  Middle East and Northern Africa              11
# ...

# %%
combined=pd.merge(raw_df2, raw_df3, on='Happiness Rank', how='outer')

# %%
final_df =combined.rename(columns={'Country_x': 'Country', 'Happiness Score_x': 'Happiness Score(2015)','Economy (GDP per Capita)_x':'GDP per Capita(2015)','Happiness Score_y':'Happiness Score(2016)','Economy (GDP per Capita)_y	':'GDP per Capita(2016)' })

# %%
final_df
# Out:
#                       Country                         Region_x  \
# 0                 Switzerland                   Western Europe
# 1                     Iceland                   Western Europe
# 2                     Denmark                   Western Europe
# 3                      Norway                   Western Europe
# 4                      Canada                    North America
# 5                     Finland                   Western Europe
# 6                 Netherlands                   Western Europe
# 7                      Sweden                   Western Europe
# 8                 New Zealand        Australia and New Zealand
# 9                   Australia        Australia and New Zealand
# 10                     Israel  Middle East and Northern Africa
# 11                 Costa Rica      Latin America and Caribbean
# 12                    Austria                   Western Europe
# 13                     Mexico      Latin America and Caribbean
# ...

# %%
final =final_df[['Country', 'Happiness Rank', 'Happiness Score(2015)', 'GDP per Capita(2015)','Happiness Score(2016)','']].copy()
