# %%
import pandas as pd
import csv

# %%
file = "GDI_data.csv"

# %%
raw_df = pd.read_csv(file, error_bad_lines=False, sep=",", encoding='cp1252')
                    
raw_df
# Out:
#                                           Country Name country code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...
