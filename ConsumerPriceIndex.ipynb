# %%
import pandas as pd

# %%
# The path to our CSV file
cpi = "semi_clean_2yeardata.csv"

# Read our Kickstarter data into pandas
raw_cpi_df = pd.read_csv(cpi)
raw_cpi_df.head()
# Out:
#   Country Name  Country Code  \
# 0       Brazil           223
# 1       Brazil           223
# 2       Brazil           223
# 3       Brazil           223
# 4       Brazil           223
#
#                                       Indicator Name   Indicator Code  \
# 0  Consumer Price Index, All items, Percentage ch...    PCPI_PC_PP_PT
# 1  Consumer Price Index, All items, Percentage ch...    PCPI_PC_PP_PT
# 2  Consumer Price Index, All items, Percentage ch...    PCPI_PC_PP_PT
# 3  Consumer Price Index, All items, Percentage ch...  PCPI_PC_CP_A_PT
# 4  Consumer Price Index, All items, Percentage ch...  PCPI_PC_CP_A_PT
#
#   Attribute         2014       2014Q1       2014M1       2014M2       2014M3  \
# 0     Value  6.329152227          NaN          NaN          NaN          NaN
# 1     Value          NaN  2.124811778          NaN          NaN          NaN
# 2     Value          NaN          NaN  0.550140353  0.689712698  0.920048462
# ...

# %%
raw_cpi_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        'Attribute', '2014', '2014Q1', '2014M1', '2014M2', '2014M3', '2014Q2',
#        '2014M4', '2014M5', '2014M6', '2014Q3', '2014M7', '2014M8', '2014M9',
#        '2014Q4', '2014M10', '2014M11', '2014M12', '2015', '2015Q1', '2015M1',
#        '2015M2', '2015M3', '2015Q2', '2015M4', '2015M5', '2015M6', '2015Q3',
#        '2015M7', '2015M8', '2015M9', '2015Q4', '2015M10', '2015M11', '2015M12',
#        '2016', '2016Q1', '2016M1', '2016M2', '2016M3', '2016Q2', '2016M4',
#        '2016M5', '2016M6', '2016Q3', '2016M7', '2016M8', '2016M9', '2016Q4',
#        '2016M10', '2016M11', '2016M12', '2017M1', '2017M2',
#        'Common Reference Period'],
#       dtype='object')

# %%
cpi_df = raw_cpi_df.loc[:,['Country Name', 'Indicator Name', 'Attribute', '2014', '2015','2016']]
# cpi_df
cpi_df["Indicator Name"].unique()
cpi_df = cpi_df.loc[cpi_df['Indicator Name'] == "Consumer Price Index, All items"]
cpi_df = cpi_df.loc[cpi_df['Attribute'] == "Value"]
final_cpi_df = cpi_df.dropna()
final_cpi_df
# Out:
#                            Country Name                   Indicator Name  \
# 28                               Brazil  Consumer Price Index, All items
# 49                               France  Consumer Price Index, All items
# 216                            Bulgaria  Consumer Price Index, All items
# 421                            Colombia  Consumer Price Index, All items
# 475                              Canada  Consumer Price Index, All items
# 644                       Cote d'Ivoire  Consumer Price Index, All items
# 717                             Croatia  Consumer Price Index, All items
# 1072                            Germany  Consumer Price Index, All items
# 1211                              Gabon  Consumer Price Index, All items
# 1227              China, P.R.: Mainland  Consumer Price Index, All items
# 1527                             Greece  Consumer Price Index, All items
# 1763   Afghanistan, Islamic Republic of  Consumer Price Index, All items
# ...

# %%
final_cpi_df.to_excel('final_cpi_data.xls')

# %%
happiness2015 = "happiness_2015.csv" 
happiness2015_df = pd.read_csv(happiness2015)
happiness2015_df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happy_2015 = happiness2015_df.loc[:,['Country', 'Happiness Rank', 'Happiness Score']]
happy_2015.head()
# Out:
#        Country  Happiness Rank  Happiness Score
# 0  Switzerland               1            7.587
# 1      Iceland               2            7.561
# 2      Denmark               3            7.527
# 3       Norway               4            7.522
# 4       Canada               5            7.427

# %%
cpi_happy_2015 = pd.DataFrame.merge(final_cpi_df, happy_2015, on='Country')
cpi_happy_2015
